# %%
#Importing the basic libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import numpy as np
warnings.filterwarnings('ignore')

# %%
#Importing the dataset
HR_Attrition=pd.read_csv(r"C:\My files\Study\MIT\MentorMind\11th employee_attrition\Data_set\HR_Employee_Attrition.csv")
HR_Attrition.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
# Removing the special character form different column and replace it with underscore
HR_Attrition.BusinessTravel = np.where(HR_Attrition.BusinessTravel == 'Non-Travel', 'Non_Travel', HR_Attrition.BusinessTravel)

HR_Attrition.Department = np.where(HR_Attrition.Department == 'Research & Development',
                               'Research_and_Development', HR_Attrition.Department)

# %% [markdown]
# # Exploratory Data Analysis

# %%
HR_Attrition.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
#Discreptive staticstics
HR_Attrition.describe().T
# Out:
#                            count          mean          std     min      25%  \
# Age                       1470.0     36.923810     9.135373    18.0    30.00
# DailyRate                 1470.0    802.485714   403.509100   102.0   465.00
# DistanceFromHome          1470.0      9.192517     8.106864     1.0     2.00
# Education                 1470.0      2.912925     1.024165     1.0     2.00
# EmployeeCount             1470.0      1.000000     0.000000     1.0     1.00
# EmployeeNumber            1470.0   1024.865306   602.024335     1.0   491.25
# EnvironmentSatisfaction   1470.0      2.721769     1.093082     1.0     2.00
# HourlyRate                1470.0     65.891156    20.329428    30.0    48.00
# JobInvolvement            1470.0      2.729932     0.711561     1.0     2.00
# JobLevel                  1470.0      2.063946     1.106940     1.0     1.00
# JobSatisfaction           1470.0      2.728571     1.102846     1.0     2.00
# ...

# %%
HR_Attrition.duplicated().sum()
# Out:
# 0

# %%
HR_Attrition.isnull().sum()/len(HR_Attrition)*100
# Out:
# Age                         0.0
# Attrition                   0.0
# BusinessTravel              0.0
# DailyRate                   0.0
# Department                  0.0
# DistanceFromHome            0.0
# Education                   0.0
# EducationField              0.0
# EmployeeCount               0.0
# EmployeeNumber              0.0
# EnvironmentSatisfaction     0.0
# Gender                      0.0
# HourlyRate                  0.0
# JobInvolvement              0.0
# JobLevel                    0.0
# JobRole                     0.0
# JobSatisfaction             0.0
# MaritalStatus               0.0
# MonthlyIncome               0.0
# MonthlyRate                 0.0
# NumCompaniesWorked          0.0
# Over18                      0.0
# OverTime                    0.0
# PercentSalaryHike           0.0
# PerformanceRating           0.0
# RelationshipSatisfaction    0.0
# StandardHours               0.0
# StockOptionLevel            0.0
# TotalWorkingYears           0.0
# ...

# %%
# Dropping unnecessary columns.
HR_Attrition1=HR_Attrition.drop(columns=['EmployeeCount', 'Over18', 'StandardHours', 'EmployeeNumber'])

# %%
#convert the object datatype into category datatype
HR_Attrition_category=list(HR_Attrition1.select_dtypes(include=['object']).columns)

# %%
for i in HR_Attrition_category:
    HR_Attrition1[i]=HR_Attrition1[i].astype('category')

# %%
HR_Attrition1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   category
#  2   BusinessTravel            1470 non-null   category
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   category
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   category
#  8   EnvironmentSatisfaction   1470 non-null   int64
#  9   Gender                    1470 non-null   category
#  10  HourlyRate                1470 non-null   int64
#  11  JobInvolvement            1470 non-null   int64
#  12  JobLevel                  1470 non-null   int64
# ...

# %%
## Data correlation matrices
#-1 to 1
# Positive correlation: relationship of Variable in Moving in Same direction
# Negative correlation: relationship existing in inverse manner: One variable is increasing ,other variable is decreasing ,Vice-versa
# No correlation or zero: there is no existing relationship between the two variable 
HR_Attrition1.corr()
# Out:
#                                Age  DailyRate  DistanceFromHome  Education  \
# Age                       1.000000   0.010661         -0.001686   0.208034
# DailyRate                 0.010661   1.000000         -0.004985  -0.016806
# DistanceFromHome         -0.001686  -0.004985          1.000000   0.021042
# Education                 0.208034  -0.016806          0.021042   1.000000
# EnvironmentSatisfaction   0.010146   0.018355         -0.016075  -0.027128
# HourlyRate                0.024287   0.023381          0.031131   0.016775
# JobInvolvement            0.029820   0.046135          0.008783   0.042438
# JobLevel                  0.509604   0.002966          0.005303   0.101589
# JobSatisfaction          -0.004892   0.030571         -0.003669  -0.011296
# MonthlyIncome             0.497855   0.007707         -0.017014   0.094961
# MonthlyRate               0.028051  -0.032182          0.027473  -0.026084
# ...

# %%
# Attrition column is our target varible so  we convert it into numerical column
# we use label encoder for converting categorical column into numerical column
# import label encoder from sklearn library
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()
HR_Attrition1['Attrition']=le.fit_transform(HR_Attrition1['Attrition'])
HR_Attrition1.head()
# Out:
#    Age  Attrition     BusinessTravel  DailyRate                Department  \
# 0   41          1      Travel_Rarely       1102                     Sales
# 1   49          0  Travel_Frequently        279  Research_and_Development
# 2   37          1      Travel_Rarely       1373  Research_and_Development
# 3   33          0  Travel_Frequently       1392  Research_and_Development
# 4   27          0      Travel_Rarely        591  Research_and_Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 1          2  Life Sciences                        2
# 1                 8          1  Life Sciences                        3
# 2                 2          2          Other                        4
# 3                 3          4  Life Sciences                        4
# 4                 2          1        Medical                        1
#
#    Gender  ...  PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# ...

# %% [markdown]
# # Plotting a few graphs

# %%
# Data visualization ,analysing different features
HR_Attrition1.keys()
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
plot_column=['Department', 'Education','EducationField',
            'Gender','JobLevel', 'YearsInCurrentRole','JobSatisfaction','MaritalStatus','PercentSalaryHike',
             'PerformanceRating']
plot_column
# Out:
# ['Department',
#  'Education',
#  'EducationField',
#  'Gender',
#  'JobLevel',
#  'YearsInCurrentRole',
#  'JobSatisfaction',
#  'MaritalStatus',
#  'PercentSalaryHike',
#  'PerformanceRating']

# %%
#Count_Plot
fig=plt.subplots(figsize=(20,25))

for p,q in enumerate(plot_column):
    plt.subplot(5,2,p+1)
    plt.subplots_adjust(hspace=1)
    sns.countplot(x=q,data=HR_Attrition,hue='Attrition')
    plt.xticks(rotation=27)

# %%
plot_column1=['Department', 'Education','EducationField',
            'Gender','JobLevel','JobSatisfaction','MaritalStatus','PercentSalaryHike','MonthlyIncome',
             'PerformanceRating','YearsSinceLastPromotion', 'YearsWithCurrManager']
plot_column1
# Out:
# ['Department',
#  'Education',
#  'EducationField',
#  'Gender',
#  'JobLevel',
#  'JobSatisfaction',
#  'MaritalStatus',
#  'PercentSalaryHike',
#  'MonthlyIncome',
#  'PerformanceRating',
#  'YearsSinceLastPromotion',
#  'YearsWithCurrManager']

# %%
#Displot
fig=plt.subplots(figsize=(20,25))

for p,q in enumerate(plot_column1):
    plt.subplot(6,2,p+1)
    plt.subplots_adjust(hspace=1.5)
    sns.histplot(x=q,data=HR_Attrition1,kde=True,bins=50)
    plt.xticks(rotation=27)

# %%
#Barplot
fig, ax = plt.subplots(5,2, figsize=(10,26))
fig.tight_layout()
#fig, ax = plt.subplots(1, 2, gridspec_kw={'width_ratios': [3, 1]})
plt.subplots_adjust(hspace=0.5)
plt.subplots_adjust(wspace=1)
sns.barplot(data=HR_Attrition1, x='Attrition', y='Department', ax=ax[0,0])
sns.barplot(data=HR_Attrition1, x='Attrition', y='Education', ax=ax[0,1])
sns.barplot(data=HR_Attrition1, x='Attrition', y= 'EducationField', ax=ax[1,0])
sns.barplot(data=HR_Attrition1, x='Attrition', y='Gender', ax=ax[1,1])
sns.barplot(data=HR_Attrition1, x='Attrition', y='JobSatisfaction', ax=ax[2,0])
sns.barplot(data=HR_Attrition1, x='Attrition', y='MaritalStatus', ax=ax[2,1])
sns.barplot(data=HR_Attrition1, x='Attrition', y='PercentSalaryHike', ax=ax[3,0])
sns.barplot(data=HR_Attrition1, x='Attrition', y='MonthlyIncome', ax=ax[3,1])
sns.barplot(data=HR_Attrition1, x='Attrition', y='BusinessTravel', ax=ax[4,0])
sns.barplot(data=HR_Attrition1, x='Attrition', y='Age', ax=ax[4,1])
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='Age'>

# %%
HR_Attrition1.groupby('Department')['Attrition'].agg(np.mean).sort_values(ascending=False)
# Out:
# Department
# Sales                       0.206278
# Human Resources             0.190476
# Research_and_Development    0.138398
# Name: Attrition, dtype: float64

# %% [markdown]
# Sales Department has highest Attrition rate

# %%
HR_Attrition1.groupby('BusinessTravel')['Attrition'].agg(len).sort_values(ascending=False)
# Out:
# BusinessTravel
# Travel_Rarely        1043
# Travel_Frequently     277
# Non_Travel            150
# Name: Attrition, dtype: int64

# %% [markdown]
# The employee who Travel_Rarely has highest Attrition rate

# %%
HR_Attrition1.groupby('EducationField')['Attrition'].agg(np.mean).sort_values(ascending=False)
# Out:
# EducationField
# Human Resources     0.259259
# Technical Degree    0.242424
# Marketing           0.220126
# Life Sciences       0.146865
# Medical             0.135776
# Other               0.134146
# Name: Attrition, dtype: float64

# %% [markdown]
# Human Resources has most Attrition in Education Field

# %%
HR_Attrition1.groupby('Gender')['Attrition'].agg(np.mean).sort_values(ascending=False)
# Out:
# Gender
# Male      0.170068
# Female    0.147959
# Name: Attrition, dtype: float64

# %% [markdown]
# Generally male employee has highest attrition rate

# %%
HR_Attrition1.groupby('WorkLifeBalance')['Attrition'].agg(np.mean).sort_values(ascending=False)
# Out:
# WorkLifeBalance
# 1    0.312500
# 4    0.176471
# 2    0.168605
# 3    0.142217
# Name: Attrition, dtype: float64

# %% [markdown]
# The one who has WorkLifeBalace is 1 , has a greater attrition rate

# %%
 HR_Attrition1.groupby('JobLevel')['Attrition'].agg(np.mean).sort_values(ascending=False)
# Out:
# JobLevel
# 1    0.263352
# 3    0.146789
# 2    0.097378
# 5    0.072464
# 4    0.047170
# Name: Attrition, dtype: float64

# %% [markdown]
# Lower level designation has highest attrition rate

# %%
HR_Attrition1[['PerformanceRating']].value_counts().sort_values(ascending=False)
# Out:
# PerformanceRating
# 3                    1244
# 4                     226
# dtype: int64

# %% [markdown]
# Number of employee who got performace rating 3

# %%
HR_Attrition1.groupby('Age')['Attrition'].agg(np.mean).sort_values(ascending=False)
# Out:
# Age
# 19    0.666667
# 20    0.545455
# 18    0.500000
# 21    0.461538
# 58    0.357143
# 22    0.312500
# 26    0.307692
# 28    0.291667
# 23    0.285714
# 24    0.269231
# 29    0.264706
# 31    0.260870
# 25    0.230769
# 56    0.214286
# 33    0.206897
# 44    0.181818
# 32    0.180328
# 52    0.166667
# 50    0.166667
# 30    0.150000
# 41    0.150000
# 39    0.142857
# 55    0.136364
# 35    0.128205
# 47    0.125000
# 46    0.121212
# 37    0.120000
# 34    0.116883
# 51    0.105263
# 53    0.105263
# 48    0.105263
# 40    0.087719
# 36    0.086957
# 49    0.083333
# 43    0.062500
# 27    0.062500
# 45    0.048780
# 42    0.043478
# 38    0.034483
# 54    0.000000
# 57    0.000000
# 59    0.000000
# 60    0.000000
# Name: Attrition, dtype: float64

# %% [markdown]
# At younger age their is highest attrition rate

# %%
HR_Attrition1.groupby('Age')['MonthlyIncome'].agg(np.mean).sort_values(ascending=False)
# Out:
# Age
# 55    13204.181818
# 50    12697.166667
# 53    11564.157895
# 46    11457.969697
# 54    10875.833333
# 58    10705.785714
# 52    10606.888889
# 60    10268.000000
# 49     9952.875000
# 51     9632.473684
# 48     9344.789474
# 47     8931.416667
# 57     8803.000000
# 43     8444.937500
# 41     8379.825000
# 56     8248.357143
# 39     8183.357143
# 42     8074.847826
# 59     8038.100000
# 45     7811.219512
# 40     7700.947368
# 44     7114.333333
# 37     5853.860000
# 38     5721.586207
# 36     5590.913043
# 31     5525.391304
# 33     5500.500000
# 35     5425.282051
# 34     5269.220779
# 32     5092.459016
# 30     4814.850000
# 29     4584.411765
# 27     4190.416667
# 25     4144.769231
# 28     3904.833333
# 26     3531.487179
# 24     3243.923077
# 22     2950.000000
# 20     2539.363636
# 23     2515.357143
# 21     2491.461538
# 19     2075.000000
# 18     1518.375000
# Name: MonthlyIncome, dtype: float64

# %% [markdown]
# At the age 55 having highest salary and lowest salary at age of 18.

# %%
HR_Attrition1[['YearsAtCompany']].value_counts().sort_values(ascending=False)
# Out:
# YearsAtCompany
# 5                 196
# 1                 171
# 3                 128
# 2                 127
# 10                120
# 4                 110
# 7                  90
# 9                  82
# 8                  80
# 6                  76
# 0                  44
# 11                 32
# 20                 27
# 13                 24
# 15                 20
# 14                 18
# 22                 15
# 21                 14
# 12                 14
# 18                 13
# 16                 12
# 19                 11
# 17                  9
# 24                  6
# 33                  5
# 25                  4
# 26                  4
# 32                  3
# 31                  3
# 36                  2
# 29                  2
# 27                  2
# 23                  2
# 30                  1
# 34                  1
# 37                  1
# 40                  1
# dtype: int64

# %% [markdown]
# Create Dummy Variable

# %%
HR_Attrition_category1=['BusinessTravel','Department','EducationField','Gender','JobRole','MaritalStatus','OverTime']

# %%
HR_att_dummy=pd.get_dummies(HR_Attrition1,columns=HR_Attrition_category1,drop_first=True)

# %%
HR_att_dummy.shape
# Out:
# (1470, 45)

# %%
HR_att_dummy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 45 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Age                                  1470 non-null   int64
#  1   Attrition                            1470 non-null   int32
#  2   DailyRate                            1470 non-null   int64
#  3   DistanceFromHome                     1470 non-null   int64
#  4   Education                            1470 non-null   int64
#  5   EnvironmentSatisfaction              1470 non-null   int64
#  6   HourlyRate                           1470 non-null   int64
#  7   JobInvolvement                       1470 non-null   int64
#  8   JobLevel                             1470 non-null   int64
#  9   JobSatisfaction                      1470 non-null   int64
#  10  MonthlyIncome                        1470 non-null   int64
# ...

# %%
HR_att_dummy.head()
# Out:
#    Age  Attrition  DailyRate  DistanceFromHome  Education  \
# 0   41          1       1102                 1          2
# 1   49          0        279                 8          1
# 2   37          1       1373                 2          2
# 3   33          0       1392                 3          4
# 4   27          0        591                 2          1
#
#    EnvironmentSatisfaction  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2          94               3         2
# 1                        3          61               2         2
# 2                        4          92               2         1
# 3                        4          56               3         1
# 4                        1          40               3         1
#
#    JobSatisfaction  ...  JobRole_Laboratory Technician  JobRole_Manager  \
# 0                4  ...                              0                0
# 1                2  ...                              0                0
# ...

# %%
#Indentifying target variable,Here Y is target varibale and X is input variable
Y=HR_att_dummy[['Attrition']]
X=HR_att_dummy.drop(columns=['Attrition'])

# %%
X
# Out:
#       Age  DailyRate  DistanceFromHome  Education  EnvironmentSatisfaction  \
# 0      41       1102                 1          2                        2
# 1      49        279                 8          1                        3
# 2      37       1373                 2          2                        4
# 3      33       1392                 3          4                        4
# 4      27        591                 2          1                        1
# ...   ...        ...               ...        ...                      ...
# 1465   36        884                23          2                        3
# 1466   39        613                 6          1                        4
# 1467   27        155                 4          3                        2
# 1468   49       1023                 2          3                        4
# 1469   34        628                 8          3                        2
#
# ...

# %%
Y
# Out:
#       Attrition
# 0             1
# 1             0
# 2             1
# 3             0
# 4             0
# ...         ...
# 1465          0
# 1466          0
# 1467          0
# 1468          0
# 1469          0
#
# [1470 rows x 1 columns]

# %% [markdown]
# Splitting the data into train and test

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.3,random_state=42)

# %%
len(x_train),len(x_test),len(y_train),len(y_test)
# Out:
# (1029, 441, 1029, 441)

# %% [markdown]
# Built Logistic Regression Model¶

# %%
from sklearn.linear_model import LogisticRegression

# %%
#For builting model we use HR_att_dummy data and attrition_stayed is the target variable is given in problem
# Built blank model 
lr=LogisticRegression()
#Fit this object on x_train and y_train
model_lr=lr.fit(x_train, y_train)
model_lr
# Out:
# LogisticRegression()

# %%
#Predict the Attrition using x_test
y_test['Prediction_LR']=model_lr.predict(x_test)
y_test.head()
# Out:
#       Attrition  Prediction_LR
# 1041          0              0
# 184           0              0
# 1222          1              1
# 67            0              0
# 220           0              0

# %% [markdown]
# Evaluation of the Logistic Regression model

# %%
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score

# %%
print(confusion_matrix(y_test['Attrition'],y_test['Prediction_LR']))
# Out:
# [[380   0]
#  [ 60   1]]

# %%
accuracy_LR=accuracy_score(y_test['Attrition'],y_test['Prediction_LR'])
accuracy_LR=np.round(accuracy_LR,2)
print('The accuracy of the Logistic Regression model is :',accuracy_LR*100,'%')
# Out:
# The accuracy of the Logistic Regression model is : 86.0 %

# %%
print('The Classification report given below\n---------------------------------------------------------\n'
      ,classification_report(y_test['Attrition'],y_test['Prediction_LR']))
# Out:
# The Classification report given below
# ---------------------------------------------------------
#                precision    recall  f1-score   support
#
#            0       0.86      1.00      0.93       380
#            1       1.00      0.02      0.03        61
#
#     accuracy                           0.86       441
#    macro avg       0.93      0.51      0.48       441
# weighted avg       0.88      0.86      0.80       441

# %% [markdown]
# From above observation we conclude that ,their is high value of precision and recall for Attrition '0' because of
# imbalace data in prediction column, Therefore we use SMOTE model for imbalace data

# %% [markdown]
# # Logistic Regression with SMOTE model

# %%
# !pip install imblearn
from imblearn.over_sampling import SMOTE
#Apply SMOTE on training data
#step1:Create SMOTE object
sm=SMOTE(random_state=1234)
#step2:Applying this object on your x_train and y_train
X_train_new,Y_train_new=sm.fit_resample(x_train, y_train)
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ------------------------------------- 226.0/226.0 kB 87.4 kB/s eta 0:00:00
# ...
#      ------------------------------------ 298.0/298.0 kB 125.3 kB/s eta 0:00:00
# ...

# %%
#Let's balance of training data
y_train.value_counts()
# Out:
# Attrition
# 0            853
# 1            176
# dtype: int64

# %%
Y_train_new.value_counts() # There fore we got balace data for Attrition
# Out:
# Attrition
# 0            853
# 1            853
# dtype: int64

# %%
# Rebuild the model using X_train_new and Y_train_new
lr_smote=LogisticRegression()
# New Model 
Model_Smote=lr_smote.fit(X_train_new, Y_train_new)

# %%
# Predict the value
y_test['Pred_value_Smote']=Model_Smote.predict(x_test)

# %%
accuracy_smote=accuracy_score(y_test['Attrition'],y_test['Pred_value_Smote'])
accuracy_smote=np.round(accuracy_smote,2)
print('The accuracy of SMOTE model is',accuracy_smote*100,'%')
# Out:
# The accuracy of SMOTE model is 67.0 %

# %%
print('The Classification report given below\n---------------------------------------------------------\n'
      ,classification_report(y_test['Attrition'],y_test['Pred_value_Smote']))
# Out:
# The Classification report given below
# ---------------------------------------------------------
#                precision    recall  f1-score   support
#
#            0       0.91      0.69      0.78       380
#            1       0.22      0.56      0.32        61
#
#     accuracy                           0.67       441
#    macro avg       0.57      0.62      0.55       441
# weighted avg       0.81      0.67      0.72       441

# %% [markdown]
# We got less accuracy using SMOTE but the there is balance value of precision and recall

# %% [markdown]
# # 2 Decision Tree Model
# ## Building the model
# ## Splitting the data into train and test

# %%
from sklearn.model_selection import train_test_split
x_train1,x_test1,y_train1,y_test1 = train_test_split(X,Y,test_size=0.25,random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier(criterion='entropy',splitter='best',min_samples_split=3)

# %%
model_dt = dt.fit(x_train1,y_train1)
print('The model has been built successfully!!')
# Out:
# The model has been built successfully!!

# %% [markdown]
# Predicting on test data

# %%
y_test1['Dicision_Tree_Predicted'] = model_dt.predict(x_test1)

# %%
y_test1
# Out:
#       Attrition  Dicision_Tree_Predicted
# 1041          0                        0
# 184           0                        0
# 1222          1                        1
# 67            0                        0
# 220           0                        0
# ...         ...                      ...
# 571           0                        0
# 1163          0                        0
# 243           0                        0
# 1411          0                        1
# 1370          0                        0
#
# [368 rows x 2 columns]

# %% [markdown]
# Evaluating the model

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
print(confusion_matrix(y_test1['Attrition'],y_test1['Dicision_Tree_Predicted']))
# Out:
# [[274  46]
#  [ 32  16]]

# %%
accuracy_Decision_tree=accuracy_score(y_test1['Attrition'],y_test1['Dicision_Tree_Predicted'])
accuracy_Decision=np.round(accuracy_Decision_tree,2)
print('The accuracy of Decision tree model is',accuracy_Decision*100,'%')
# Out:
# The accuracy of Decision tree model is 79.0 %

# %%
print('The Classification report given below\n---------------------------------------------------------\n'
      ,classification_report(y_test1['Attrition'],y_test1['Dicision_Tree_Predicted']))
# Out:
# The Classification report given below
# ---------------------------------------------------------
#                precision    recall  f1-score   support
#
#            0       0.90      0.86      0.88       320
#            1       0.26      0.33      0.29        48
#
#     accuracy                           0.79       368
#    macro avg       0.58      0.59      0.58       368
# weighted avg       0.81      0.79      0.80       368

# %% [markdown]
# # Decision tree with SMOTE

# %%
# !pip install imblearn
from imblearn.over_sampling import SMOTE
#Apply SMOTE on training data
#step1:Create SMOTE object
sm=SMOTE(random_state=1234)
#step2:Applying this object on your x_train and y_train
X_train_new1,Y_train_new1=sm.fit_resample(x_train1, y_train1)
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
#Let's balance of training data
y_train1.value_counts()

# %%
Y_train_new1.value_counts() # There fore we got balace data for Attrition

# %%
# Rebuild the model using X_train_new1 and Y_train_new1
dt=DecisionTreeClassifier()
# New Model 
Model_Smote_dt=dt.fit(X_train_new1, Y_train_new1)

# %% [markdown]
# # Evaluating the model

# %%
# Predict the value
y_test1['Pred_value_Smote_dt']=Model_Smote.predict(x_test1)

# %%
accuracy_smote_dt=accuracy_score(y_test1['Attrition'],y_test1['Pred_value_Smote_dt'])
accuracy_smote_dt=np.round(accuracy_smote_dt,2)
print('The accuracy of SMOTE model is',accuracy_smote_dt*100,'%')
# Out:
# The accuracy of SMOTE model is 67.0 %

# %%
print('The Classification report given below\n---------------------------------------------------------\n'
      ,classification_report(y_test1['Attrition'],y_test1['Pred_value_Smote_dt']))
# Out:
# The Classification report given below
# ---------------------------------------------------------
#                precision    recall  f1-score   support
#
#            0       0.91      0.70      0.79       320
#            1       0.20      0.52      0.29        48
#
#     accuracy                           0.67       368
#    macro avg       0.56      0.61      0.54       368
# weighted avg       0.81      0.67      0.72       368

# %% [markdown]
# By applying SMOTE model on Decision tree the accuracy of model is reduced but the value
# of precision and recall is increased.

# %% [markdown]
# # 3 Random Forest model
# ## plitting the data into train and test

# %%
from sklearn.model_selection import train_test_split
x_train2,x_test2,y_train2,y_test2 = train_test_split(X,Y,test_size=0.2,random_state=1234)

# %%
len(x_train2),len(x_test2),len(y_train2),len(y_test2)
# Out:
# (1176, 294, 1176, 294)

# %% [markdown]
# Building the model

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=1000)

# %%
model_rf = rf.fit(x_train2,y_train2)
print('The model has been built successfully!!')
# Out:
# The model has been built successfully!!

# %% [markdown]
# Predicting on test data¶

# %%
y_test2['Prediction_rf'] = model_rf.predict(x_test2)

# %%
y_test2
# Out:
#       Attrition  Prediction_rf
# 520           0              0
# 286           1              0
# 347           0              0
# 1245          0              0
# 1153          1              1
# ...         ...            ...
# 1279          1              0
# 590           0              0
# 92            0              0
# 312           0              0
# 1331          0              0
#
# [294 rows x 2 columns]

# %% [markdown]
# Evaluating the model¶

# %%
print(confusion_matrix(y_test2['Attrition'],y_test2['Prediction_rf']))
# Out:
# [[247   0]
#  [ 40   7]]

# %%
accuracy_rf=accuracy_score(y_test2['Attrition'],y_test2['Prediction_rf'])
accuracy_rf=np.round(accuracy_rf,2)
print('The accuracy of Random Forest model is',accuracy_rf*100,'%')
# Out:
# The accuracy of Random Forest model is 86.0 %

# %%
print('The Classification report given below\n---------------------------------------------------------\n'
      ,classification_report(y_test2['Attrition'],y_test2['Prediction_rf']))
# Out:
# The Classification report given below
# ---------------------------------------------------------
#                precision    recall  f1-score   support
#
#            0       0.86      1.00      0.93       247
#            1       1.00      0.15      0.26        47
#
#     accuracy                           0.86       294
#    macro avg       0.93      0.57      0.59       294
# weighted avg       0.88      0.86      0.82       294

# %% [markdown]
# Random Forest with SMOTE

# %% [markdown]
# # Handling imbalace data

# %%
from imblearn.over_sampling import SMOTE
#Apply SMOTE on training data
#step1:Create SMOTE object
sm=SMOTE(random_state=1234)
#step2:Applying this object on your x_train and y_train
X_train_new2,Y_train_new2=sm.fit_resample(x_train2, y_train2)

# %%
#Let's balance of training data
y_train2.value_counts()
# Out:
# Attrition
# 0            986
# 1            190
# dtype: int64

# %%
Y_train_new2.value_counts() # There fore we got balace data for Attrition
# Out:
# Attrition
# 0            986
# 1            986
# dtype: int64

# %%
# Rebuild the model using X_train_new2 and Y_train_new2
rf = RandomForestClassifier(n_estimators=1000)
# New Model 
Model_Smote_rf=rf.fit(X_train_new2, Y_train_new2)

# %% [markdown]
# # Evaluating the model

# %%
# Predict the value
y_test2['Pred_value_Smote_rf']=Model_Smote.predict(x_test2)

# %%
# accuracy_smote_rf=accuracy_score(y_test2['Attrition'],y_test2['Pred_value_Smote_rf'])
accuracy_smote_rf=np.round(accuracy_smote_rf,2)
print('The accuracy of SMOTE model is',accuracy_smote_rf*100,'%')
# Out:
# The accuracy of SMOTE model is 66.0 %

# %%
print('The Classification report given below\n---------------------------------------------------------\n'
      ,classification_report(y_test2['Attrition'],y_test2['Pred_value_Smote_rf']))
# Out:
# The Classification report given below
# ---------------------------------------------------------
#                precision    recall  f1-score   support
#
#            0       0.92      0.65      0.76       247
#            1       0.28      0.72      0.40        47
#
#     accuracy                           0.66       294
#    macro avg       0.60      0.69      0.58       294
# weighted avg       0.82      0.66      0.70       294

# %% [markdown]
# # Draw a ROC Curves
# ## 1) ROC Curve for Logistic Regression model

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
import matplotlib.pyplot as plt

# %%
#split the data into train and test
Y=HR_att_dummy[['Attrition']]
X=HR_att_dummy.drop(columns=['Attrition'])
x_train,x_test,y_train, y_test= train_test_split(X, Y, test_size=0.2, random_state=2)

# %%
#Crate blank Logistic regression model and fit x_train and y_train.
lr=LogisticRegression()
model_lr=lr.fit(x_train, y_train)
model_lr
# Out:
# LogisticRegression()

# %%
# generate a no skill prediction (majority class)
ns_probs = [0 for _ in range(len(y_test))]

# %%
# predict probabilities
lr_probs = model_lr.predict_proba(x_test)
# keep probabilities for the positive outcome only
lr_probs = lr_probs[:, 1]

# %%
# calculate scores
ns_auc = roc_auc_score(y_test, ns_probs)
lr_auc = roc_auc_score(y_test, lr_probs)

# %%
# predict probabilities
lr_probs = model_lr.predict_proba(x_test)
# keep probabilities for the positive outcome only
lr_probs = lr_probs[:, 1]
# calculate scores
ns_auc = roc_auc_score(y_test, ns_probs)
lr_auc = roc_auc_score(y_test, lr_probs)

# %%
# summarize scores
print('No Skill: ROC AUC=%.3f' % (ns_auc))
print('Logistic: ROC AUC=%.3f' % (lr_auc))
# Out:
# No Skill: ROC AUC=0.500
# Logistic: ROC AUC=0.738

# %%
# calculate roc curves
ns_fpr, ns_tpr, _ = roc_curve(y_test, ns_probs)
lr_fpr, lr_tpr, _ = roc_curve(y_test, lr_probs)

# %%
# plot the roc curve for the model
plt.plot(ns_fpr, ns_tpr, linestyle='--',label='No Skill')
plt.plot(lr_fpr, lr_tpr, marker='.',label='Logistic')
# axis labels
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.show()

# %% [markdown]
# Conclusion:1)The more that the ROC curve hugs the top left corner of the plot,the better the model does at classifying the data into categories. 2)To quantify this, we can calculate the AUC (area under the curve) which tells us how much of the plot is located under the curve. 3)The closer AUC is to 1, the better the model.A model with an AUC equal to 0.5 would be a perfectly diagonal line and it would represent a model that is no better than a model that makes random classifications. 4) The Model which has the highest AUC, which indicates that it has the highest area under the curve and is the best model at correctly classifying observations into categories. 5)Here the AUC value=0.768 ,so that this model has been Acceptable discrimination.

# %% [markdown]
# # 1.1 ROC Curve for Logistic Regression using SMOTE

# %%
# Rebuild the model using X_train_new and Y_train_new
lr_smote=LogisticRegression()
# New Model 
Model_Smote=lr_smote.fit(X_train_new, Y_train_new)

# %%
# generate a no skill prediction (majority class)
ns_probs = [0 for _ in range(len(y_test))]

# %%
# predict probabilities
lr_probs = Model_Smote.predict_proba(x_test)
# keep probabilities for the positive outcome only
lr_probs = lr_probs[:, 1]

# %%
# calculate scores
ns_auc = roc_auc_score(y_test, ns_probs)
lr_auc = roc_auc_score(y_test, lr_probs)

# %%
# summarize scores
print('No Skill: ROC AUC=%.3f' % (ns_auc))
print('Logistic with SMOTE: ROC AUC=%.3f' % (lr_auc))
# Out:
# No Skill: ROC AUC=0.500
# Logistic with SMOTE: ROC AUC=0.712

# %%
# calculate roc curves
ns_fpr, ns_tpr, _ = roc_curve(y_test, ns_probs)
lr_fpr, lr_tpr, _ = roc_curve(y_test, lr_probs)

# %%
# plot the roc curve for the model
plt.plot(ns_fpr, ns_tpr, linestyle='--',label='No Skill')
plt.plot(lr_fpr, lr_tpr, marker='.',label='Logistic_SMOTE')
# axis labels
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.show()

# %% [markdown]
# Conclustion=The closer AUC is to 1, the better the model.A model with an AUC equal to 0.5 would be a perfectly diagonal line and it would represent a model that is no better than a model that makes random classifications. Here the value of AUC is 0.711 ,means this model is Acceptable dicrimination for classification

# %% [markdown]
# # 2 ROC Curve for Decision Tree classifier

# %%
#Create Decision Tree Classifier object
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier(criterion='entropy',splitter='best',min_samples_split=3)

# %%
from sklearn.model_selection import train_test_split
x_train1,x_test1,y_train1,y_test1 = train_test_split(X,Y,test_size=0.25,random_state=2)

# %%
# generate a no skill prediction (majority class)
ns_probs1 = [0 for _ in range(len(y_test1))]

# %%
#fit the x_train1,y_train1 in model
model_dt = dt.fit(x_train1,y_train1)

# %%
# predict probabilities
dt_probs = model_dt.predict_proba(x_test1)
# keep probabilities for the positive outcome only
dt_probs = dt_probs[:, 1]

# %%
# calculate scores
ns_auc = roc_auc_score(y_test1, ns_probs1)
dt_auc = roc_auc_score(y_test1, dt_probs)

# %%
# summarize scores
print('No Skill: ROC AUC=%.3f' % (ns_auc))
print('Decision Tree: ROC AUC=%.3f' % (dt_auc))
# Out:
# No Skill: ROC AUC=0.500
# Decision Tree: ROC AUC=0.607

# %%
# calculate roc curves
ns_fpr, ns_tpr, _ = roc_curve(y_test1, ns_probs1)
dt_fpr, dt_tpr, _ = roc_curve(y_test1, dt_probs)

# %%
# plot the roc curve for the model
plt.plot(ns_fpr, ns_tpr, linestyle='--',label='No Skill')
plt.plot(dt_fpr, dt_tpr, marker='.',label='Decision_Tree')
# axis labels
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.show()

# %% [markdown]
# Conclusion=The closer AUC is to 1, the better the model.A model with an AUC equal to 0.5 would be a perfectly diagonal line and it would represent a model that is no better than a model that makes random classifications. Here the value of AUC is 0.591,which is closer to 0.5 ,means this model is not good for classification.

# %% [markdown]
# # 2.1 ROC Curve for Decision Tree classifier with SMOTE

# %%
# Rebuild the model using X_train_new1 and Y_train_new1
dt=DecisionTreeClassifier()
# New Model 
Model_Smote_dt=dt.fit(X_train_new1, Y_train_new1)

# %%
# predict probabilities
dt_probs = Model_Smote_dt.predict_proba(x_test1)
# keep probabilities for the positive outcome only
dt_probs = dt_probs[:, 1]

# %%
# calculate scores
ns_auc = roc_auc_score(y_test1, ns_probs1)
dt_auc = roc_auc_score(y_test1, dt_probs)

# %%
# summarize scores
print('No Skill: ROC AUC=%.3f' % (ns_auc))
print('Decision_Tree_SMOTE: ROC AUC=%.3f' % (dt_auc))
# Out:
# No Skill: ROC AUC=0.500
# Decision_Tree_SMOTE: ROC AUC=0.937

# %%
# calculate roc curves
ns_fpr, ns_tpr, _ = roc_curve(y_test1, ns_probs1)
dt_fpr, dt_tpr, _ = roc_curve(y_test1, dt_probs)

# %%
# plot the roc curve for the model
plt.plot(ns_fpr, ns_tpr, linestyle='--',label='No Skill')
plt.plot(dt_fpr, dt_tpr, marker='.',label='Decision_Tree_SMOTE')
# axis labels
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.show()

# %% [markdown]
# Conclusion=The closer AUC is to 1, the better the model.A model with an AUC equal to 0.5 would be a perfectly diagonal line and it would represent a model that is no better than a model that makes random classifications. Here the value of AUC is arround 0.940 ,means this model is good for classification.

# %% [markdown]
# # 3 ROC Curve for Random Forest

# %%
from sklearn.model_selection import train_test_split
x_train2,x_test2,y_train2,y_test2 = train_test_split(X,Y,test_size=0.2,random_state=2)

# %%
#Create Randam Forest object and fit the x_train2,y_train2 in the model
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=500)
model_rf = rf.fit(x_train2,y_train2)

# %%
# generate a no skill prediction (majority class)
ns_probs2 = [0 for _ in range(len(y_test2))]

# %%
# predict probabilities
rf_probs = model_rf.predict_proba(x_test2)
# keep probabilities for the positive outcome only
rf_probs = rf_probs[:, 1]

# %%
# calculate scores
ns_auc = roc_auc_score(y_test2, ns_probs2)
rf_auc = roc_auc_score(y_test2, rf_probs)

# %%
# summarize scores
print('No Skill: ROC AUC=%.3f' % (ns_auc))
print('Random Forest: ROC AUC=%.3f' % (rf_auc))
# Out:
# No Skill: ROC AUC=0.500
# Random Forest: ROC AUC=0.824

# %%
# calculate roc curves
ns_fpr, ns_tpr, _ = roc_curve(y_test2, ns_probs2)
rf_fpr, rf_tpr, _ = roc_curve(y_test2, rf_probs)

# %%
# plot the roc curve for the model
plt.plot(ns_fpr, ns_tpr, linestyle='--',label='No Skill')
plt.plot(rf_fpr, rf_tpr, marker='.',label='Random Forest')
# axis labels
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.show()

# %% [markdown]
# Conclusion=The closer AUC is to 1, the better the model.A model with an AUC equal to 0.5 would be a perfectly diagonal line and it would represent a model that is no better than a model that makes random classifications. Here the value of AUC is arround 830 ,which closer to 1, means this model has Excellent dicrimination.

# %% [markdown]
# # 3.1 ROC Curve for Random Forest with SMOTE

# %%
# Rebuild the model using X_train_new2 and Y_train_new2
rf = RandomForestClassifier(n_estimators=1000)
# New Model 
Model_Smote_rf=rf.fit(X_train_new2, Y_train_new2)

# %%
# predict probabilities
rf_probs = Model_Smote_rf.predict_proba(x_test)
# keep probabilities for the positive outcome only
rf_probs = rf_probs[:, 1]

# %%
# calculate scores
ns_auc = roc_auc_score(y_test2, ns_probs2)
rf_auc = roc_auc_score(y_test2, rf_probs)

# %%
# summarize scores
print('No Skill: ROC AUC=%.3f' % (ns_auc))
print('Random Forest_SMOTE: ROC AUC=%.3f' % (rf_auc))
# Out:
# No Skill: ROC AUC=0.500
# Random Forest_SMOTE: ROC AUC=0.974

# %%
# calculate roc curves
ns_fpr, ns_tpr, _ = roc_curve(y_test2, ns_probs2)
rf_fpr, rf_tpr, _ = roc_curve(y_test2, rf_probs)

# %%
# plot the roc curve for the model
plt.plot(ns_fpr, ns_tpr, linestyle='--',label='No Skill')
plt.plot(rf_fpr, rf_tpr, marker='.',label='Random Forest SMOTE')
# axis labels
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.show()

# %% [markdown]
# Conclusion=The closer AUC is to 1, the better the model.A model with an AUC equal to 0.5 would be a perfectly diagonal line and it would represent a model that is no better than a model that makes random classifications. Here the value of AUC is 0.985,which is closer to 1 ,means this model is better for classification.
